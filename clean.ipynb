# %% [markdown]
# # Channel Volume

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Business_case/Data/Channel_Volume.csv")
df
# Out:
#       Location          Industry  Edition     Category  Subcategory  \
# 0            1  Alcoholic Drinks     2022         Beer         Beer
# 1            1  Alcoholic Drinks     2022         Beer         Beer
# 2            1  Alcoholic Drinks     2022         Beer         Beer
# 3            1  Alcoholic Drinks     2022         Beer         Beer
# 4            1  Alcoholic Drinks     2022         Beer         Beer
# ...        ...               ...      ...          ...          ...
# 8463         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 8464         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 8465         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 8466         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 8467         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
#
#       Hierarchy_Level         Data_Type                          Outlet  \
# 0                   1  Off-trade Volume  Food/drink/tobacco specialists
# ...

# %%
df = df.rename(columns = {"Volume": "Volume (millions of liters)"})

# %%
mask = df["Unit"] == "000 litres"
df.loc[mask, "Volume (millions of liters)"] = df.loc[mask, "Volume (millions of liters)"].div(1000)
df
# Out:
#       Location          Industry  Edition     Category  Subcategory  \
# 0            1  Alcoholic Drinks     2022         Beer         Beer
# 1            1  Alcoholic Drinks     2022         Beer         Beer
# 2            1  Alcoholic Drinks     2022         Beer         Beer
# 3            1  Alcoholic Drinks     2022         Beer         Beer
# 4            1  Alcoholic Drinks     2022         Beer         Beer
# ...        ...               ...      ...          ...          ...
# 8463         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 8464         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 8465         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 8466         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 8467         7  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
#
#       Hierarchy_Level         Data_Type                          Outlet  \
# 0                   1  Off-trade Volume  Food/drink/tobacco specialists
# ...

# %%
df = df.drop(columns=["Industry", "Unit", "Edition", "Year_date"])
df
# Out:
#       Location     Category  Subcategory  Hierarchy_Level         Data_Type  \
# 0            1         Beer         Beer                1  Off-trade Volume
# 1            1         Beer         Beer                1  Off-trade Volume
# 2            1         Beer         Beer                1  Off-trade Volume
# 3            1         Beer         Beer                1  Off-trade Volume
# 4            1         Beer         Beer                1  Off-trade Volume
# ...        ...          ...          ...              ...               ...
# 8463         7  Cider/Perry  Cider/Perry                1  Off-trade Volume
# 8464         7  Cider/Perry  Cider/Perry                1  Off-trade Volume
# 8465         7  Cider/Perry  Cider/Perry                1  Off-trade Volume
# 8466         7  Cider/Perry  Cider/Perry                1  Off-trade Volume
# 8467         7  Cider/Perry  Cider/Perry                1  Off-trade Volume
#
# ...

# %%
print(df.isna().any())
# Out:
# Location                       False
# Category                        True
# Subcategory                    False
# Hierarchy_Level                False
# Data_Type                      False
# Outlet                         False
# Outlet_Hierarchy               False
# Year_text                      False
# Volume (millions of liters)    False
# dtype: bool

# %%
print(df[df["Category"].isna()])
# Out:
# Empty DataFrame
# Columns: [Location, Category, Subcategory, Hierarchy_Level, Data_Type, Outlet, Outlet_Hierarchy, Year_text, Volume (millions of liters)]
# Index: []

# %% [markdown]
# # Company Share

# %%
df2 = pd.read_csv("Business_case/Data/Company_Share_GBO_unit.csv")
df2
# Out:
#       Location          Industry  Subcategory_ID  Hierarchy_Level  \
# 0            8  Alcoholic Drinks              15                1
# 1            8  Alcoholic Drinks              15                1
# 2            8  Alcoholic Drinks              15                1
# 3            8  Alcoholic Drinks              15                1
# 4            8  Alcoholic Drinks              15                1
# ...        ...               ...             ...              ...
# 5436         8  Alcoholic Drinks              11                4
# 5437         8  Alcoholic Drinks              11                4
# 5438         8  Alcoholic Drinks              11                4
# 5439         8  Alcoholic Drinks              11                4
# 5440         8  Alcoholic Drinks              11                4
#
#          Data_Type    Global_Brand_Owner            Unit  Year_text Year_date  \
# 0     Total Volume            Diageo Plc  million litres       2017  31/12/17
# ...

# %%
for column in df2.columns:
    print(column, ": ", df2[column].unique())
# Out:
# Location :  [8]
# Industry :  ['Alcoholic Drinks']
# Subcategory_ID :  [15 14 16 13 17  2  5  3  1  4  8  9  7  6 12 10 11]
# Hierarchy_Level :  [1 3 2 4]
# Data_Type :  ['Total Volume']
# Global_Brand_Owner :  ['Diageo Plc' 'Pernod Ricard Groupe' 'Hite Jinro Co Ltd'
#  'Thai Beverage PCL' 'Suntory Holdings Ltd'
#  'Beijing Shunxin Agriculture Co Ltd'
#  'Allied Blenders & Distillers Pvt Ltd' 'Bacardi & Co Ltd' 'Lotte Group'
#  'Alliance Global Group Inc' 'Russian Standard Corp' 'San Miguel Corp'
#  'Sazerac Co Inc' 'Muhak Co Ltd' 'Brown-Forman Corp'
#  'Campari Milano SpA, Davide' 'Sujiu Group' 'Luzhou Lao Jiao Co Ltd'
#  'Jing Brand Co Ltd' 'Tanduay Distillers Inc'
#  'Sichuan Yibin Wuliangye Distillery Co Ltd' 'Radico Khaitan Ltd'
#  'Takara Holdings Inc' 'Cia Muller de Bebidas Ltda'
#  'Capital Wine Group Ltd' 'John Distilleries Pvt Ltd'
#  'Stock Spirits Group' 'Heaven Hill Distilleries Inc'
#  'Marie Brizard & Roger International SAS' 'William Grant & Sons Ltd'
# ...

# %%
df2 = df2.rename(columns={"Volume": "Volume (millions of liters)"})
df2
# Out:
#       Location          Industry  Subcategory_ID  Hierarchy_Level  \
# 0            8  Alcoholic Drinks              15                1
# 1            8  Alcoholic Drinks              15                1
# 2            8  Alcoholic Drinks              15                1
# 3            8  Alcoholic Drinks              15                1
# 4            8  Alcoholic Drinks              15                1
# ...        ...               ...             ...              ...
# 5436         8  Alcoholic Drinks              11                4
# 5437         8  Alcoholic Drinks              11                4
# 5438         8  Alcoholic Drinks              11                4
# 5439         8  Alcoholic Drinks              11                4
# 5440         8  Alcoholic Drinks              11                4
#
#          Data_Type    Global_Brand_Owner            Unit  Year_text Year_date  \
# 0     Total Volume            Diageo Plc  million litres       2017  31/12/17
# ...

# %%
df2 = df2.drop(columns=["Industry", "Unit", "Year_date", "Year_minus_2016"])

# %% [markdown]
# # Market Sizes

# %%
df3 = pd.read_csv("Business_case/Data/Market_Sizes.csv")
df3
# Out:
#       Location          Industry  Subcategory  Hierarchy_Level  \
# 0            1  Alcoholic Drinks           13                1
# 1            1  Alcoholic Drinks           13                1
# 2            1  Alcoholic Drinks           13                1
# 3            1  Alcoholic Drinks           13                1
# 4            1  Alcoholic Drinks           13                1
# ...        ...               ...          ...              ...
# 1216         7  Alcoholic Drinks           10                4
# 1217         7  Alcoholic Drinks           10                4
# 1218         7  Alcoholic Drinks           10                4
# 1219         7  Alcoholic Drinks           10                4
# 1220         7  Alcoholic Drinks           10                4
#
#             Data_Type         Unit  \
# 0     Total Value RSP  USD million
# 1     Total Value RSP  USD million
# 2     Total Value RSP  USD million
# 3     Total Value RSP  USD million
# ...

# %%
for column in df3.columns:
    print(column, ": ", df3[column].unique())
# Out:
# Location :  [1 2 3 4 5 6 7]
# Industry :  ['Alcoholic Drinks']
# Subcategory :  [13 16 17 14 15  4  5  3  2  1  6  7  8  9 12 11 10]
# Hierarchy_Level :  [1 3 2 4]
# Data_Type :  ['Total Value RSP']
# Unit :  ['USD million']
# Current_Constant :  ['Historic Constant 2021 Prices, Forecast Constant 2021 Prices']
# Currency_Conversion :  ['Historic Fixed 2021 Exchange Rates, Forecast Fixed 2021 Exchange Rates']
# Year :  [2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026]
# Year_date :  ['12/31/2016' '12/31/2017' '12/31/2018' '12/31/2019' '12/31/2020'
#  '12/31/2021' '12/31/2022' '12/31/2023' '12/31/2024' '12/31/2025'
#  '12/31/2026' '12/31/1987' '12/31/1966' '12/31/1976']
# RSP :  [149.912 156.954 161.843 ...  56.574  57.382  58.232]
# Volume :  [ 68.437  70.7    70.691  69.074  67.887  68.804  69.816  70.587  71.338
#   72.045  72.744   2.101   2.129   2.122   2.128   2.164   2.197   2.232
#    2.266   2.299   2.332   2.364  24.704  23.662  22.282  20.882  20.819
# ...

# %%
df3 = df3.drop(columns=["Industry", "Unit", "Year_date", "Year_minus_2016", "Year_minus_2022", "Edition"])
df3
# Out:
#       Location  Subcategory  Hierarchy_Level        Data_Type  \
# 0            1           13                1  Total Value RSP
# 1            1           13                1  Total Value RSP
# 2            1           13                1  Total Value RSP
# 3            1           13                1  Total Value RSP
# 4            1           13                1  Total Value RSP
# ...        ...          ...              ...              ...
# 1216         7           10                4  Total Value RSP
# 1217         7           10                4  Total Value RSP
# 1218         7           10                4  Total Value RSP
# 1219         7           10                4  Total Value RSP
# 1220         7           10                4  Total Value RSP
#
#                                        Current_Constant  \
# 0     Historic Constant 2021 Prices, Forecast Consta...
# 1     Historic Constant 2021 Prices, Forecast Consta...
# ...

# %%
# Checking for null values

print(df3.isna().any())
# Out:
# Location                       False
# Subcategory                    False
# Hierarchy_Level                False
# Data_Type                      False
# Current_Constant               False
# Currency_Conversion            False
# Year                           False
# RSP (USD Millions)             False
# Volume (millions of liters)    False
# dtype: bool

# %%
df3["Volume"] = df3["Volume"].div(1000000)

# %%
df3 = df3.rename(columns={"RSP": "RSP (USD Millions)", "Volume": "Volume (millions of liters)"})
df3
# Out:
#       Location  Subcategory  Hierarchy_Level        Data_Type  \
# 0            1           13                1  Total Value RSP
# 1            1           13                1  Total Value RSP
# 2            1           13                1  Total Value RSP
# 3            1           13                1  Total Value RSP
# 4            1           13                1  Total Value RSP
# ...        ...          ...              ...              ...
# 1216         7           10                4  Total Value RSP
# 1217         7           10                4  Total Value RSP
# 1218         7           10                4  Total Value RSP
# 1219         7           10                4  Total Value RSP
# 1220         7           10                4  Total Value RSP
#
#                                        Current_Constant  \
# 0     Historic Constant 2021 Prices, Forecast Consta...
# 1     Historic Constant 2021 Prices, Forecast Consta...
# ...

# %%
# Save files

# %%
df.to_csv("Preprocessed_data/Channel_Volume.csv")
df2.to_csv("Preprocessed_data/Company_Share_GBO_unit.csv")
df3.to_csv("Preprocessed_data/Market_Sizes.csv")
